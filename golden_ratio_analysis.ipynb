# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
gr_data = pd.read_csv('golden_ratio_house_data.csv')

# %%
gr_data_corr = gr_data.drop(['Unnamed: 0', 'Block'], axis = 1)
gr_data_matrix = gr_data_corr.corr()
sns.heatmap(gr_data_matrix, annot=True)

# see a bunch of negative correlation with qualify rate. this is good because bigger qualify rate = we're choosing houses that have less median income, more poverty, structure is older, employment rate is less
# jk i lied. poverty rate should not be negatively correlating with qualify rate 
# jk it makes sense: more houses qualify = less people in poverty in that block, makes sense bc we are only doing houses with who could feasibly pay off the solar panels
# Out:
# <Axes: >
